# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

np.random.seed(42)

#Simulation dataset (e.g., student scores)
data={
    "Math_Score":np.random.normal(70,10,100),
    "Science_Score":np.random.normal(72,12,100),
    "Hours_Studied":np.random.normal(5,2,100)
}
df=pd.DataFrame(data)
print(df.head(),"\n")
# Out:
#    Math_Score  Science_Score  Hours_Studied
# 0   74.967142      55.015551       5.715575
# 1   68.617357      66.952256       6.121569
# 2   76.476885      67.887426       7.166102
# 3   85.230299      62.372673       7.107604
# 4   67.658466      70.064571       2.244661

# %%
mean_math=df["Math"]

# %%
#G.DATA DISTRIBUTION(Histogram)
plt.figure(figsize=())

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

np.random.seed(42)

experience =np.random.randint(1,11,50)#years of experience
salary=experience * 8+np.random.normal(0,3,50)#salary trend with noise

df=pd.DataFrame({"Experience":experience,"Salary":salary})
print("Sample Data:")
print(df.head(),"\n")
# Out:
# Sample Data:
#    Experience     Salary
# 0           7  58.467635
# 1           4  28.337469
# 2           8  64.626591
# 3           5  34.120990
# 4           7  52.015442

# %%
x=df[["Experience"]]
y= df[["Salary"]]
X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0],"\n")
# Out:
# Intercept: [0.65421502]
# Slope: [7.80281249]

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print("---- MODEL EVALUATION ----")
print("Mean Absolute Error (MAE):",mae)
print("Mean Squared Error(MSE):",mse)
print("Root Mean Squared Error(RMSE):",rmse)
print("R-squared:",r2)
# Out:
# ---- MODEL EVALUATION ----
# Mean Absolute Error (MAE): 2.679830745523859
# Mean Squared Error(MSE): 11.26309588208506
# Root Mean Squared Error(RMSE): 3.356053617284006
# R-squared: 0.9773720877802984

# %%
plt.scatter(x,y,color="blue",label="Actual Data")
plt.plot(x, model.predict(x),color="red",label="Regression Line")
plt.xlabel("Experience(Years)")
plt.ylabel("Salary")
plt.title("Linear Regression Model")
plt.legend()
plt.show()
